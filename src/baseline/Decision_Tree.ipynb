# %%
import pandas as pd
from pathlib import Path

# %%
# Xác định thư mục gốc của project
PROJECT_ROOT = Path.cwd().parents[1]

# Đường dẫn tới file dữ liệu
DATA_PATH = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / "BTCUSDT"
    / "BTCUSDT_1m_baseline.csv"
)

# Đọc dữ liệu
df = pd.read_csv(DATA_PATH)

print(f"Data shape: {df.shape}")
# Out:
# Data shape: (20160, 13)

# %%
df.head()
# Out:
#        open      high       low     close    volume  quote_asset_volume  \
# 0  93576.00  93610.93  93537.50  93610.93   8.21827        7.689788e+05
# 1  93610.93  93652.00  93606.20  93652.00  12.14029        1.136551e+06
# 2  93652.00  93702.15  93635.98  93702.15  11.60597        1.087101e+06
# 3  93702.14  93702.15  93654.48  93677.98   8.72958        8.177203e+05
# 4  93677.98  93677.99  93659.92  93661.20   5.24749        4.915570e+05
#
#    number_of_trades  taker_buy_base_volume  taker_buy_quote_volume  target  \
# 0              2631                3.95157           369757.326529       1
# 1              1273                4.08887           382791.500172       1
# 2              1095                5.86840           549682.868570       0
# 3              1461                2.48203           232486.113080       0
# 4               988                0.48880            45786.251963       1
#
#    hour  minute  day_of_week
# 0     0       0            2
# 1     0       1            2
# 2     0       2            2
# 3     0       3            2
# 4     0       4            2
