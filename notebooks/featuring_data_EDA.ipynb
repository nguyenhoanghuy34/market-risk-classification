# %%
import pandas as pd

# %%
FEATURE_PATH = r"D:\Subject\CV2026\Market Risk Classification\market-risk-classification\data\feature_store\BTCUSDT\BTCUSDT_feature_store.parquet"

# %%
df_feature = pd.read_parquet(
    FEATURE_PATH
)

# %%
df_feature.shape
# Out:
# (1999017, 77)

# %%
df_feature.head()
# Out:
#             open_time     open     high      low    close    volume  \
# 0 2017-08-17 05:39:00  4291.37  4291.37  4291.37  4291.37  0.134767
# 1 2017-08-17 05:40:00  4291.37  4291.37  4291.37  4291.37  0.000000
# 2 2017-08-17 05:41:00  4291.37  4291.37  4291.37  4291.37  0.000000
# 3 2017-08-17 05:42:00  4291.37  4291.37  4291.37  4291.37  0.000000
# 4 2017-08-17 05:43:00  4291.37  4291.37  4291.37  4291.37  0.000000
#
#                close_time  quote_asset_volume  number_of_trades  \
# 0 2017-08-17 05:39:59.999          578.335061                 1
# 1 2017-08-17 05:40:59.999            0.000000                 0
# 2 2017-08-17 05:41:59.999            0.000000                 0
# 3 2017-08-17 05:42:59.999            0.000000                 0
# 4 2017-08-17 05:43:59.999            0.000000                 0
#
#    taker_buy_base_volume  ...  close_lag_3  volume_lag_1  volume_lag_2  \
# 0                    0.0  ...      4320.00      0.098390      0.373933
# ...

# %%
df_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999017 entries, 0 to 1999016
# Data columns (total 77 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   open_time               datetime64[ns]
#  1   open                    float64
#  2   high                    float64
#  3   low                     float64
#  4   close                   float64
#  5   volume                  float64
#  6   close_time              datetime64[ns]
#  7   quote_asset_volume      float64
#  8   number_of_trades        int64
#  9   taker_buy_base_volume   float64
#  10  taker_buy_quote_volume  float64
#  11  ignore                  int64
#  12  SMA_5                   float64
#  13  SMA_10                  float64
#  14  SMA_20                  float64
#  15  SMA_50                  float64
#  16  SMA_100                 float64
#  17  EMA_5                   float64
#  18  EMA_10                  float64
#  19  EMA_20                  float64
# ...

# %%
features = df_feature.columns.tolist()

len(features), features
# Out:
# (77,
#  ['open_time',
#   'open',
#   'high',
#   'low',
#   'close',
#   'volume',
#   'close_time',
#   'quote_asset_volume',
#   'number_of_trades',
#   'taker_buy_base_volume',
#   'taker_buy_quote_volume',
#   'ignore',
#   'SMA_5',
#   'SMA_10',
#   'SMA_20',
#   'SMA_50',
#   'SMA_100',
#   'EMA_5',
#   'EMA_10',
#   'EMA_20',
#   'EMA_50',
#   'EMA_100',
#   'RSI_7',
#   'RSI_14',
#   'RSI_21',
#   'ROC_5',
#   'ROC_10',
#   'Momentum_5',
#   'Momentum_10',
#   'MACD',
#   'MACD_signal',
#   'MACD_hist',
#   'BB_upper_20',
#   'BB_middle_20',
#   'BB_lower_20',
#   'BB_width_20',
#   'ATR_14',
#   'ATR_28',
#   'Volatility_5',
#   'Volatility_10',
#   'Volatility_20',
#   'Volatility_50',
#   'OBV',
#   'VWAP',
#   'Volume_MA_5',
#   'Volume_MA_10',
#   'Volume_MA_20',
#   'Return_1',
#   'Log_Return_1',
#   'Return_5',
#   'Log_Return_5',
#   'Return_10',
#   'Log_Return_10',
#   'Rolling_Mean_5',
#   'Rolling_STD_5',
#   'Rolling_Mean_10',
#   'Rolling_STD_10',
# ...

# %%
df_feature.isnull().sum().sort_values(
    ascending=False
).head(20)
# Out:
# open_time                 0
# open                      0
# high                      0
# low                       0
# close                     0
# volume                    0
# close_time                0
# quote_asset_volume        0
# number_of_trades          0
# taker_buy_base_volume     0
# taker_buy_quote_volume    0
# ignore                    0
# SMA_5                     0
# SMA_10                    0
# SMA_20                    0
# SMA_50                    0
# SMA_100                   0
# EMA_5                     0
# EMA_10                    0
# EMA_20                    0
# dtype: int64

# %%
df_feature.describe().T
# Out:
#                   count                           mean                  min  \
# open_time       1999017  2019-07-16 09:10:13.497634048  2017-08-17 05:39:00
# open          1999017.0                   13011.663704               2830.0
# high          1999017.0                   13022.172639               2830.0
# low           1999017.0                     13000.9587               2817.0
# close         1999017.0                   13011.656047               2817.0
# ...                 ...                            ...                  ...
# RSI_14_lag_2  1999017.0                      50.323986             0.038198
# RSI_14_lag_3  1999017.0                      50.323981             0.038198
# MACD_lag_1    1999017.0                       0.113413         -1367.102499
# MACD_lag_2    1999017.0                       0.113378         -1367.102499
# MACD_lag_3    1999017.0                       0.113344         -1367.102499
#
# ...
